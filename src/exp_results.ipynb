# %% [markdown]
# ## Collection of Experimental Records

# %% [markdown]
# ### CIFAR10 Experiments
#
# Upperbounds, MLE, EWC, SI, LP, MLP, CNN-3, ResNet-2.

# %%
import numpy as np

tasks = np.arange(1, 6)
upperbound = np.array([96.15, 86.4, 91.8, 96.8, 96.0])
mle = np.array([83.55, 78.55, 75.45, 86.9, 95.65])
ewc = np.array([87.05, 70.8, 77.7, 95.05, 96.2])
si = np.array([80.8, 71.35, 73.25, 95.25, 95.9])
vcl = np.array([92.3, 78.0, 80.3, 92.45, 91.45])

# Create plot with similar style
plt.figure(figsize=(4.5, 3))  # Adjust the figure size to your preference
plt.plot(tasks, upperbound, 'o-', label='Upperbound', color='black')
plt.plot(tasks, mle, 's-', label='MLE', color='blue')
plt.plot(tasks, ewc, '^-', label='EWC (λ=1)', color='red')
plt.plot(tasks, si, 'x-', label='SI (c=1)', color='orange')
plt.plot(tasks, vcl, 'd-', label='VCL', color='purple')

# Set labels and title to match the screenshot style
plt.xlabel('Tests on Previous Tasks after Task 5')
plt.ylabel('Accuracy (%)')
plt.title('Split CIFAR10 Tasks with CNN-3', fontsize=10)

# Set y-axis to range from 0 to 100
plt.ylim(40, 100)

# Add grid, legend, and ensure the plot is tight so everything fits
plt.grid(True, which='both', axis='y', linestyle='--', linewidth=0.5)
plt.legend(loc='lower right', frameon=False)
plt.tight_layout()

# plt.savefig('./figures/cnn3_scifar10.jpg', format='jpg', dpi=300)

# Display the plot
plt.show()

# %%
import numpy as np

upp_resnet = [97.95, 88.35, 93.55, 97.7, 91.75]
mle_resnet = [64.85, 65.55, 72.2, 83.95, 97.55]
ewc_resnet = [75.9, 68.05, 73.65, 88.4, 97.0]  # lambda = 1
si_resnet = [68.75, 69.7, 83.35, 92.65, 97.15]  # c_si = 1
vcl_resnet = [89.75, 72.15, 69.3, 71.4, 89.4]

tasks = np.arange(1, 6)
upperbound = np.array(upp_resnet)
mle = np.array(mle_resnet)
ewc = np.array(ewc_resnet)
si = np.array(si_resnet)
vcl = np.array(vcl_resnet)

# Create plot with similar style
plt.figure(figsize=(4.5, 3))  # Adjust the figure size to your preference
plt.plot(tasks, upperbound, 'o-', label='Upperbound', color='black')
plt.plot(tasks, mle, 's-', label='MLE', color='blue')
plt.plot(tasks, ewc, '^-', label='EWC (λ=1)', color='red')
plt.plot(tasks, si, 'x-', label='SI (c=1)', color='orange')
plt.plot(tasks, vcl, 'd-', label='VCL', color='purple')

# Set labels and title to match the screenshot style
plt.xlabel('Tests on Previous Tasks after Task 5')
plt.ylabel('Accuracy (%)')
plt.title('Split CIFAR10 Tasks with ResNet-2', fontsize=10)

# Set y-axis to range from 0 to 100
plt.ylim(40, 100)

# Add grid, legend, and ensure the plot is tight so everything fits
plt.grid(True, which='both', axis='y', linestyle='--', linewidth=0.5)
plt.legend(loc='lower right', frameon=False, fontsize='small')
plt.tight_layout()

# plt.savefig('./figures/resnet2_scifar10.jpg', format='jpg', dpi=300)

# Display the plot
plt.show()

# %% [markdown]
# ## CIFAR100 Experiments
#
# Upperbounds, MLE, EWC, SI, LP, MLP, CNN-3, ResNet-4.

# %%
import numpy as np

upp_cnn = [78.9, 76.7, 80.1, 76.9, 78.6, 80.5, 78.9, 77.4, 76.5, 82.3]
mle_cnn = [7.4, 5.5, 8.1, 6.9, 4.4, 9, 20.5, 14.1, 12.5, 74.5]
ewc_cnn = [7.3, 3, 7, 5.9, 4.9, 9.1, 23.1, 11.7, 10.6, 84]  # lambda=1
si_cnn = [9.1, 4.7, 7.4, 7.4, 4.0, 10.0, 21.1, 13.9, 11.3, 71.9]  # c_si = 1
vcl_cnn = [55.7, 53.1, 60.0, 53.4, 59.2, 59.7, 61.7, 59.2, 53.0, 60.5]

tasks = np.arange(1, 11)
upperbound = np.array(upp_cnn)
mle = np.array(mle_cnn)
ewc = np.array(ewc_cnn)
si = np.array(si_cnn)
vcl = np.array(vcl_cnn)

# Create plot with similar style
plt.figure(figsize=(4.5, 3))  # Adjust the figure size to your preference
plt.plot(tasks, upperbound, 'o-', label='Upperbound', color='black')
plt.plot(tasks, mle, 's-', label='MLE', color='blue')
plt.plot(tasks, ewc, '^-', label='EWC (λ=1k)', color='red')
plt.plot(tasks, si, 'x-', label='SI (c=1)', color='orange')
plt.plot(tasks, vcl, 'd-', label='VCL', color='purple')

# Set labels and title to match the screenshot style
plt.xlabel('Tests on Previous Tasks after Task 10')
plt.ylabel('Accuracy (%)')
plt.title('Split CIFAR100 Tasks with CNN-3', fontsize=10)

# Set y-axis to range from 0 to 100
plt.ylim(0, 100)

# Set x-axis labels and rotate them
task_labels = list(range(1,11))
plt.xticks(tasks, task_labels)

# Add grid, legend, and ensure the plot is tight so everything fits
plt.grid(True, which='both', axis='y', linestyle='--', linewidth=0.5)
plt.legend(loc='lower right', frameon=False, fontsize='small')
plt.legend(loc='upper left', bbox_to_anchor=(1, 1), frameon=False, fontsize='small')

plt.tight_layout()

# plt.savefig('figures/cnn3_scifar100.jpg', format='jpg', dpi=300)

# Display the plot
plt.show()

# %%
import numpy as np

upp_rn = [76.1, 74.1, 79.4, 74.3, 78.3, 76.7, 77.5, 72.2, 81.8, 80.8]
mle_rn = [9.1, 2.4, 9.3, 5.7, 4.5, 8.3, 19.1, 7.9, 10.9, 86.2]
ewc_rn = [10.2, 2.1, 8.1, 5.4, 5.4, 7.8, 20.3, 7.4, 11.0, 86.2]
si_rn = [2.6, 22.1, 10.4, 7.5, 10.0, 5.8, 3.2, 18.1, 10.6, 2.6, ]
vcl_rn = [46.8, 38.2, 46.9, 41.5, 43.9, 41.6, 46.8, 48.2, 48.6, 54.5]

tasks = np.arange(1, 11)
upperbound = np.array(upp_rn)
mle = np.array(mle_rn)
ewc = np.array(ewc_rn)
si = np.array(si_rn)
vcl = np.array(vcl_rn)

# Create plot with similar style
plt.figure(figsize=(4.5, 3))  # Adjust the figure size to your preference
plt.plot(tasks, upperbound, 'o-', label='Upperbound', color='black')
plt.plot(tasks, mle, 's-', label='MLE', color='blue')
plt.plot(tasks, ewc, '^-', label='EWC (λ=1k)', color='red')
plt.plot(tasks, si, 'x-', label='SI (c=1)', color='orange')
plt.plot(tasks, vcl, 'd-', label='VCL', color='purple')

# Set labels and title to match the screenshot style
plt.xlabel('Tests on Previous Tasks after Task 10')
plt.ylabel('Accuracy (%)')
plt.title('Split CIFAR100 Tasks with ResNet-4', fontsize=10)

# Set y-axis to range from 0 to 100
plt.ylim(0, 100)

# Set x-axis labels and rotate them
task_labels = list(range(1,11))
plt.xticks(tasks, task_labels)

# Add grid, legend, and ensure the plot is tight so everything fits
plt.grid(True, which='both', axis='y', linestyle='--', linewidth=0.5)
legend = plt.legend(loc='upper left', bbox_to_anchor=(1, 1), frameon=False, fontsize='small')

# plt.savefig('./figures/resnet4_scifar100.jpg', format='jpg', dpi=300, bbox_extra_artists=(legend,), bbox_inches='tight')

plt.tight_layout()

# Display the plot
plt.show()

# %% [markdown]
# ### Depict the figures on a single plot

# %%
import matplotlib.pyplot as plt
import numpy as np

# Data for CNN-3 Split CIFAR10
tasks_cnn3_scifar10 = np.arange(1, 6)
upperbound_cnn3_scifar10 = np.array([96.15, 86.4, 91.8, 96.8, 96.0])
mle_cnn3_scifar10 = np.array([83.55, 78.55, 75.45, 86.9, 95.65])
ewc_cnn3_scifar10 = np.array([87.05, 70.8, 77.7, 95.05, 96.2])
si_cnn3_scifar10 = np.array([80.8, 71.35, 73.25, 95.25, 95.9])
vcl_cnn3_scifar10 = np.array([92.3, 78.0, 80.3, 92.45, 91.45])

# Data for ResNet-2 Split CIFAR10
tasks_resnet2_scifar10 = np.arange(1, 6)
upp_resnet2_scifar10 = [97.95, 88.35, 93.55, 97.7, 91.75]
mle_resnet2_scifar10 = [64.85, 65.55, 72.2, 83.95, 97.55]
ewc_resnet2_scifar10 = [75.9, 68.05, 73.65, 88.4, 97.0]  # lambda = 1
si_resnet2_scifar10 = [68.75, 69.7, 83.35, 92.65, 97.15]  # c_si = 1
vcl_resnet2_scifar10 = [89.75, 72.15, 69.3, 71.4, 89.4]

# Data for CNN-3 Split CIFAR100
tasks_cnn3_scifar100 = np.arange(1, 11)
upp_cnn3_scifar100 = [78.9, 76.7, 80.1, 76.9, 78.6, 80.5, 78.9, 77.4, 76.5, 82.3]
mle_cnn3_scifar100 = [7.4, 5.5, 8.1, 6.9, 4.4, 9, 20.5, 14.1, 12.5, 74.5]
ewc_cnn3_scifar100 = [7.3, 3, 7, 5.9, 4.9, 9.1, 23.1, 11.7, 10.6, 84]  # lambda=1
si_cnn3_scifar100 = [9.1, 4.7, 7.4, 7.4, 4.0, 10.0, 21.1, 13.9, 11.3, 71.9]  # c_si = 1
vcl_cnn3_scifar100 = [55.7, 53.1, 60.0, 53.4, 59.2, 59.7, 61.7, 59.2, 53.0, 60.5]

# Data for ResNet-4 Split CIFAR100
tasks_resnet4_scifar100 = np.arange(1, 11)
upp_resnet4_scifar100 = [76.1, 74.1, 79.4, 74.3, 78.3, 76.7, 77.5, 72.2, 81.8, 80.8]
mle_resnet4_scifar100 = [9.1, 2.4, 9.3, 5.7, 4.5, 8.3, 19.1, 7.9, 10.9, 86.2]
ewc_resnet4_scifar100 = [10.2, 2.1, 8.1, 5.4, 5.4, 7.8, 20.3, 7.4, 11.0, 86.2]
si_resnet4_scifar100 = [2.6, 22.1, 10.4, 7.5, 10.0, 5.8, 3.2, 18.1, 10.6, 2.6]
vcl_resnet4_scifar100 = [46.8, 38.2, 46.9, 41.5, 43.9, 41.6, 46.8, 48.2, 48.6, 54.5]

# %%
# Setup for 2x2 subplots
fig, axs = plt.subplots(2, 2, figsize=(12, 8))

# Plot for CNN-3 CIFAR10
axs[0, 0].set_ylim([60, 100])
tasks_labels = ['Task 1', 'Task 2', 'Task 3', 'Task 4', 'Task 5']
axs[0, 0].set_xticks(tasks_cnn3_scifar10)
axs[0, 0].set_xticklabels(tasks_labels)

axs[0, 0].plot(tasks_cnn3_scifar10, upperbound_cnn3_scifar10, 'o-', label='Upperbound', color='black')
axs[0, 0].plot(tasks_cnn3_scifar10, mle_cnn3_scifar10, 's-', label='MLE', color='blue')
axs[0, 0].plot(tasks_cnn3_scifar10, ewc_cnn3_scifar10, '^-', label='EWC', color='red')
axs[0, 0].plot(tasks_cnn3_scifar10, si_cnn3_scifar10, 'x-', label='SI', color='orange')
axs[0, 0].plot(tasks_cnn3_scifar10, vcl_cnn3_scifar10, 'd-', label='VCL', color='purple')
axs[0, 0].set_title('CNN-3 on Split CIFAR10')
# axs[0, 0].set_xlabel('Tasks')
axs[0, 0].set_ylabel('Accuracy')
# axs[0, 0].legend()

# Plot for ResNet-2 CIFAR10
axs[0, 1].set_ylim([60, 100])
tasks_labels = ['Task 1', 'Task 2', 'Task 3', 'Task 4', 'Task 5']
axs[0, 1].set_xticks(tasks_resnet2_scifar10)
axs[0, 1].set_xticklabels(tasks_labels)
axs[0, 1].plot(tasks_resnet2_scifar10, upp_resnet2_scifar10, 'o-', label='Upperbound', color='black')
axs[0, 1].plot(tasks_resnet2_scifar10, mle_resnet2_scifar10, 's-', label='MLE', color='blue')
axs[0, 1].plot(tasks_resnet2_scifar10, ewc_resnet2_scifar10, '^-', label='EWC', color='red')
axs[0, 1].plot(tasks_resnet2_scifar10, si_resnet2_scifar10, 'x-', label='SI', color='orange')
axs[0, 1].plot(tasks_resnet2_scifar10, vcl_resnet2_scifar10, 'd-', label='VCL', color='purple')
axs[0, 1].set_title('ResNet-2 on Split CIFAR10')
# axs[0, 1].set_xlabel('Tasks')
axs[0, 1].set_ylabel('Accuracy')
axs[0, 1].legend(loc='upper left', bbox_to_anchor=(1, 1), frameon=False)

# Plot for CNN-3 CIFAR100
axs[1, 0].set_ylim([0, 90])
tasks_labels = [f'Task {i+1}' for i in range(10)]
axs[1, 0].set_xticks(tasks_cnn3_scifar100)
axs[1, 0].set_xticklabels(tasks_labels, rotation=45)
axs[1, 0].plot(tasks_cnn3_scifar100, upp_cnn3_scifar100, 'o-', label='Upperbound', color='black')
axs[1, 0].plot(tasks_cnn3_scifar100, mle_cnn3_scifar100, 's-', label='MLE', color='blue')
axs[1, 0].plot(tasks_cnn3_scifar100, ewc_cnn3_scifar100, '^-', label='EWC', color='red')
axs[1, 0].plot(tasks_cnn3_scifar100, si_cnn3_scifar100, 'x-', label='SI', color='orange')
axs[1, 0].plot(tasks_cnn3_scifar100, vcl_cnn3_scifar100, 'd-', label='VCL', color='purple')
axs[1, 0].set_title('CNN-3 on Split CIFAR100')
# axs[1, 0].set_xlabel('Tasks')
axs[1, 0].set_ylabel('Accuracy')
# axs[1, 0].legend()

# Plot for ResNet-4 CIFAR100
axs[1, 1].set_ylim([0, 90])
tasks_labels = [f'Task {i+1}' for i in range(10)]
axs[1, 1].set_xticks(tasks_resnet4_scifar100)
axs[1, 1].set_xticklabels(tasks_labels, rotation=45)
axs[1, 1].plot(tasks_resnet4_scifar100, upp_resnet4_scifar100, 'o-', label='Upperbound', color='black')
axs[1, 1].plot(tasks_resnet4_scifar100, mle_resnet4_scifar100, 's-', label='MLE', color='blue')
axs[1, 1].plot(tasks_resnet4_scifar100, ewc_resnet4_scifar100, '^-', label='EWC', color='red')
axs[1, 1].plot(tasks_resnet4_scifar100, si_resnet4_scifar100, 'x-', label='SI', color='orange')
axs[1, 1].plot(tasks_resnet4_scifar100, vcl_resnet4_scifar100, 'd-', label='VCL', color='purple')
axs[1, 1].set_title('ResNet-4 on Split CIFAR100')
# axs[1, 1].set_xlabel('Tasks')
axs[1, 1].set_ylabel('Accuracy')
axs[1, 1].legend(loc='upper left', bbox_to_anchor=(1, 1), frameon=False)


plt.tight_layout()
plt.savefig('./figures/cifar_exp.jpg', format='jpg', dpi=300)

plt.show()

# %% [markdown]
# ## Effects of Applying Normalizing Flows

# %%
import pandas as pd

# %%
cnn_c100p = pd.read_csv('./csv_files/disc_conv_s_cifar100_prev.csv')['Value'].values
cnn_c100n = pd.read_csv('./csv_files/disc_conv_s_cifar100_now.csv')['Value'].values

res_c100p = pd.read_csv('./csv_files/disc_resnet_s_cifar100_prev.csv')['Value'].values
res_c100n = pd.read_csv('./csv_files/disc_resnet_s_cifar100_now.csv')['Value'].values

cnn_c10p = pd.read_csv('./csv_files/disc_conv_s_cifar10_prev.csv')['Value'].values
cnn_c10n = pd.read_csv('./csv_files/disc_conv_s_cifar10_now.csv')['Value'].values

res_c10p = pd.read_csv('./csv_files/disc_resnet_s_cifar10_prev.csv')['Value'].values
res_c10n = pd.read_csv('./csv_files/disc_resnet_s_cifar10_now.csv')['Value'].values

# %%
g = lambda x:print(f"{sum(x)/len(x):.4f}")
g(res_c100p)
g(res_c100n)
print(res_c100p[-1], res_c100n[-1])
# Out:
# 41.6092
# 52.3598
# 41.38999938964844 49.83000183105469

# %%
import matplotlib.pyplot as plt
import numpy as np

c10_tasks = np.arange(1, 6)
c10_tasks_ticks = [f"{i}" for i in range(1, 6)]
c100_tasks = np.arange(1, 11)
c100_tasks_ticks = [f"Task {i}" if i == 1 else i for i in range(1, 11)]

# Define the styles for the plots
marker_style = 'd-'
colors = {
    'ResNet-4': 'royalblue',
    'ResNet-4 with SNF': 'tomato',  # Darker shade of purple
    'CNN-3': 'blue',
    'CNN-3 with SNF': 'red'  # Darker shade of skyblue
}

# Create a new figure with subplots
fig, axs = plt.subplots(1, 2, figsize=(12, 4))  # 1x2 subplot structure

# fig.suptitle('Mean Accuracies over Tasks on Split CIFAR10 (left) / CIFAR100 (right)', fontsize=14, y=1.0)
# fig.text(0.5, -0.04, '# Tasks Already Trained', ha='center', va='center', fontsize=12)

axs[0].plot(c10_tasks, cnn_c10p, marker_style, label='CNN-3', color=colors['CNN-3'])
axs[0].plot(c10_tasks, cnn_c10n, marker_style, label='CNN-3 with SNF', color=colors['CNN-3 with SNF'])
axs[0].plot(c10_tasks, res_c10p, marker_style, label='ResNet-2', color=colors['ResNet-4'])
axs[0].plot(c10_tasks, res_c10n, marker_style, label='ResNet-2 with SNF', color=colors['ResNet-4 with SNF'])
axs[0].set_xlabel('#Tasks already trained', fontsize=11)
axs[0].set_ylabel('Mean Accuracy', fontsize=12)
axs[0].set_title('Mean accuracies over tasks on Split CIFAR10', fontsize=11)
axs[0].set_ylim(0, 100)
axs[0].set_xticks(c10_tasks)
axs[0].set_xticklabels(c10_tasks_ticks)
axs[0].grid(True, which='both', axis='y', linestyle='--', linewidth=0.5)
# axs[0].legend(loc='lower right', frameon=False, fontsize='small')

# Second subplot for CNN-3
axs[1].plot(c100_tasks, cnn_c100p, marker_style, label='CNN-3', color=colors['CNN-3'])
axs[1].plot(c100_tasks, cnn_c100n, marker_style, label='CNN-3 with SNF', color=colors['CNN-3 with SNF'])
axs[1].plot(c100_tasks, res_c100p, marker_style, label='ResNet-4', color=colors['ResNet-4'])
axs[1].plot(c100_tasks, res_c100n, marker_style, label='ResNet-4 with SNF', color=colors['ResNet-4 with SNF'])
axs[1].set_xlabel('#Tasks already trained', fontsize=11)
# axs[1].set_ylabel('Mean Accuracy')
axs[1].set_title('Mean accuracies over tasks on Split CIFAR100', fontsize=11)
axs[1].set_ylim(0, 100)
axs[1].set_xticks(c100_tasks)
axs[1].set_xticklabels(c100_tasks_ticks)
axs[1].grid(True, which='both', axis='y', linestyle='--', linewidth=0.5)
axs[1].legend(loc='upper left', bbox_to_anchor=(1, 1), frameon=False)

# Adjust layout to prevent overlap
plt.tight_layout()

# Save the entire figure
plt.savefig('./figures/snf_aligned.jpg', format='jpg', dpi=300, bbox_inches='tight')

# Display the figure
plt.show()

# %% [markdown]
# ## Replicated Experiments
#
# MLP on Split MNIST

# %%
ewc_mlp = [93.61, 38.0, 81.59, 89.82, 99.39]
si_mlp = [87.94, 42.6, 84.63, 89.72, 99.24]
lp_mlp = [88.60, 41.57, 91.40, 93.20, 99.29]
vcl_mlp = [99.81087470449172, 96.86581782566111, 99.03948772678763, 97.83484390735146, 98.68885526979324]

import numpy as np
tasks = np.arange(1, 6)
ewc = np.array(ewc_mlp)
si = np.array(si_mlp)
lp = np.array(lp_mlp)
vcl = np.array(vcl_mlp)

# Create plot with similar style
plt.figure(figsize=(4.5, 3))  # Adjust the figure size to your preference
plt.plot(tasks, lp, 's-', label='LP', color='blue')
plt.plot(tasks, ewc, '^-', label='EWC (λ=1)', color='red')
plt.plot(tasks, si, 'x-', label='SI (c=1)', color='orange')
plt.plot(tasks, vcl, 'd-', label='VCL', color='purple')

# Set labels and title to match the screenshot style
plt.xlabel('Tests on Previous Tasks after Task 5')
plt.ylabel('Accuracy (%)')
plt.title('Split MNIST Tasks with MLP', fontsize=10)

# Set y-axis to range from 0 to 100
plt.ylim(0, 100)

# Add grid, legend, and ensure the plot is tight so everything fits
plt.grid(True, which='both', axis='y', linestyle='--', linewidth=0.5)
plt.legend(loc='lower right', frameon=False, fontsize='small')
plt.tight_layout()

plt.savefig('./figures/repl_smnist.jpg', format='jpg', dpi=300)

# Display the plot
plt.show()
